# %%
# !pip install pandas
# !pip install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.9/250.9 kB 6.3 MB/s eta 0:00:005.4 MB/s eta 0:00:01
# ...

# %% [markdown]
# Abaixo vamos carregar os dados

# %%
import pandas as pd

pib_muni = pd.read_excel('PIB dos Municípios - base de dados 2010-2021.xlsx')

# %%
pib_muni
# Out:
#         Ano  Código da Grande Região Nome da Grande Região  \
# 0      2010                        1                 Norte
# 1      2010                        1                 Norte
# 2      2010                        1                 Norte
# 3      2010                        1                 Norte
# 4      2010                        1                 Norte
# ...     ...                      ...                   ...
# 66820  2021                        5          Centro-oeste
# 66821  2021                        5          Centro-oeste
# 66822  2021                        5          Centro-oeste
# 66823  2021                        5          Centro-oeste
# 66824  2021                        5          Centro-oeste
#
#        Código da Unidade da Federação Sigla da Unidade da Federação  \
# 0                                  11                            RO
# 1                                  11                            RO
# ...
